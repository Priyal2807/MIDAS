# %% [markdown]
# Importing the necessary files for using the twitter API

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import API

# %% [markdown]
# Importing json for being able to analyse the tweets after being dumped in a json file

# %%
import json

# %% [markdown]
# Creating variables for authentication and connecting to the twitter api

# %%
acc_token = " "
acc_token_sec = " "
cons_key = " "
cons_key_sec = " "

auth = OAuthHandler(cons_key, cons_key_sec)
auth.set_access_token(acc_token, acc_token_sec)

api = API(auth)

# %% [markdown]
# user_timeline() is a method that allows to access the tweets from a specific user's timeline, count is the number of tweets requested

# %%
val = api.user_timeline(screen_name = 'midasIIITD', count = 100, include_rts = True)

# %% [markdown]
# Here, the values returned are of the type status because of the tweepy library used

# %%
print(val)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000021CDEC21CF8>, _json={'created_at': 'Wed Apr 10 09:01:29 +0000 2019', 'id': 1115902611599822852, 'id_str': '1115902611599822852', 'text': 'Clarification: Our earlier post which indicates that the interview has been done is referring to the interviews of… https://t.co/x8Etf6qEOn', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/x8Etf6qEOn', 'expanded_url': 'https://twitter.com/i/web/status/1115902611599822852', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1021355762575073281, 'id_str': '1021355762575073281', 'name': 'MIDAS IIITD', 'screen_name': 'midasIIITD', 'location': 'New Delhi, India', 'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.', 'url': 'https://t.co/Uwg7oSM6mE', 'entities': {'url': {'urls': [{'url': 'https://t.co/Uwg7oSM6mE', 'expanded_url': 'http://midas.iiitd.edu.in/', 'display_url': 'midas.iiitd.edu.in', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 290, 'friends_count': 43, 'listed_count': 0, 'created_at': 'Mon Jul 23 11:26:04 +0000 2018', 'favourites_count': 143, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 344, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 4, 10, 9, 1, 29), id=1115902611599822852, id_str='1115902611599822852', text='Clarification: Our earlier post which indicates that the interview has been done is referring to the interviews of… https://t.co/x8Etf6qEOn', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/x8Etf6qEOn', 'expanded_url': 'https://twitter.com/i/web/status/1115902611599822852', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000021CDEC21CF8>, _json={'id': 1021355762575073281, 'id_str': '1021355762575073281', 'name': 'MIDAS IIITD', 'screen_name': 'midasIIITD', 'location': 'New Delhi, India', 'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.', 'url': 'https://t.co/Uwg7oSM6mE', 'entities': {'url': {'urls': [{'url': 'https://t.co/Uwg7oSM6mE', 'expand ...

# %% [markdown]
# Here, for every tweet(variable created) in 'val' we are saving the contents to a json file named myFile.json which can then be parsed

# %%
for tweet in val:                           
    with open('myFile.json', 'w', encoding='utf8') as file:
        json.dump(tweet._json, file)

# %% [markdown]
# The next cell is used to print the contents of the json file

# %%
from pprint import pprint

with open('myFile.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Feb 16 16:57:51 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'blog.acolyer.org/2019/02/13/bey…',
#                         'expanded_url': 'https://blog.acolyer.org/2019/02/13/beyond-news-contents-the-role-of-social-context-for-fake-news-detection/',
#                         'indices': [19, 42],
#                         'url': 'https://t.co/qNFzJ7ZHki'}],
#               'user_mentions': [{'id': 73426884,
#                                  'id_str': '73426884',
#                                  'indices': [3, 17],
#                                  'name': 'Debanjan Mahata',
#                                  'screen_name': 'debanjanbhucs'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1096815936986705921,
#  'id_str': '1096815936986705921',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'und',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 1,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sat Feb 16 14:43:55 +0000 2019',
#                       'entities': {'hashtags': [],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'blog.acolyer.org/2019/02/13/bey…',
#                                              'expanded_url': 'https://blog.acolyer.org/2019/02/13/beyond-news-contents-the-role-of-social-context-for-fake-news-detection/',
#                                              'indices': [0, 23],
#                                              'url': 'https://t.co/qNFzJ7ZHki'}],
#                                    'user_mentions': []},
#                       'favorite_count': 1,
#                       'favorited': False,
#                       'geo': None,
#                       'id': 1096782229919928320,
#                       'id_str': '1096782229919928320',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'und',
#                       'place': {'attributes': {},
#                                 'bounding_box': {'coordinates': [[[-74.337166,
#                                                                    40.553141],
#                                                                   [-74.292843,
#                                                                    40.553141],
#                                                                   [-74.292843,
#                                                                    40.585914],
#                                                                   [-74.337166,
#                                                                    40.585914]]],
#                                                  'type': 'Polygon'},
#                                 'contained_within': [],
#                                 'country': 'United States',
#                                 'country_code': 'US',
#                                 'full_name': 'Iselin, NJ',
#                                 'id': '812a6cfdd31b4a5f',
#                                 'name': 'Iselin',
#                                 'place_type': 'city',
#                                 'url': 'https://api.twitter.com/1.1/geo/id/812a6cfdd31b4a5f.json'},
#                       'possibly_sensitive': False,
#                       'retweet_count': 1,
#                       'retweeted': False,
#                       'source': '<a href="http://twitter.com/download/iphone" '
#                                 'rel="nofollow">Twitter for iPhone</a>',
#                       'text': 'https://t.co/qNFzJ7ZHki',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Fri Sep 11 16:48:50 +0000 2009',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'Applied Research Scientist, '
#                                               'Machine Learning, NLP, Data '
#                                               'Mining, Information Retrieval, '
#                                               'Tabla, Hindusthani Classical '
#                                               'Music... enthusiast. Opinions '
#                                               'are my own.',
#                                'entities': {'description': {'urls': []},
#                                             'url': {'urls': [{'display_url': 'linkedin.com/in/debanjanmah…',
#                                                               'expanded_url': 'http://linkedin.com/in/debanjanmahata',
#                                                               'indices': [0,
#                                                                           23],
#                                                               'url': 'https://t.co/HkjsGaPqCq'}]}},
#                                'favourites_count': 418,
#                                'follow_request_sent': False,
#                                'followers_count': 284,
#                                'following': False,
#                                'friends_count': 363,
#                                'geo_enabled': True,
#                                'has_extended_profile': True,
#                                'id': 73426884,
#                                'id_str': '73426884',
#                                'is_translation_enabled': False,
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 29,
#                                'location': 'New York, USA',
#                                'name': 'Debanjan Mahata',
#                                'notifications': False,
#                                'profile_background_color': 'EDECE9',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/73426884/1401745278',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/3606302625/43333c34e6fbd17f7368dbf92604cd1d_normal.jpeg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3606302625/43333c34e6fbd17f7368dbf92604cd1d_normal.jpeg',
#                                'profile_link_color': 'FA743E',
#                                'profile_sidebar_border_color': 'FFFFFF',
#                                'profile_sidebar_fill_color': 'E3E2DE',
#                                'profile_text_color': '634047',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'debanjanbhucs',
#                                'statuses_count': 810,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'https://t.co/HkjsGaPqCq',
#                                'utc_offset': None,
#                                'verified': False}},
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': 'RT @debanjanbhucs: https://t.co/qNFzJ7ZHki',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'MIDAS is a group of researchers at IIIT-Delhi who '
#                          'study, analyze, and build different multimedia '
#                          'systems for society leveraging multimodal '
#                          'information.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#                                          'expanded_url': 'http://midas.iiitd.edu.in/',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/Uwg7oSM6mE'}]}},
#           'favourites_count': 143,
#           'follow_request_sent': False,
#           'followers_count': 290,
#           'following': True,
#           'friends_count': 43,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 1021355762575073281,
#           'id_str': '1021355762575073281',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': 'New Delhi, India',
#           'name': 'MIDAS IIITD',
#           'notifications': False,
#           'profile_background_color': 'F5F8FA',
#           'profile_background_image_url': None,
#           'profile_background_image_url_https': None,
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'midasIIITD',
#           'statuses_count': 344,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/Uwg7oSM6mE',
#           'utc_offset': None,
#           'verified': False}}

# %% [markdown]
# myFile is then loaded into data where the key and the value item pair are then used to extract the necessary details

# %%
f = open('myFile.json')
data = json.load(f)
f.close()

# %%
for (k, v) in data.items():
    if k=="created_at" or k=="favorite_count" or k == "retweet_count" or k == "text":
        print("Key:" + k)
        print("Value:" + str(v))
# Out:
# Key:created_at
# Value:Sat Feb 16 16:57:51 +0000 2019
# Key:text
# Value:RT @debanjanbhucs: https://t.co/qNFzJ7ZHki
# Key:retweet_count
# Value:1
# Key:favorite_count
# Value:0
